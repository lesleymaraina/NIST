# %% [markdown]
# ### All Data: Consensus Genotype
# Size_Sample_Deletions_AllData_2000
#
# * Size Ranges
# * Training Dataset size : 2000

# %%
"""
Imports
"""
import pandas as pd
import numpy as np
import graphviz
import io
from fancyimpute import KNN
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.grid_search import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import LeaveOneOut
from scipy.stats import ks_2samp
from scipy import stats
from matplotlib import pyplot
from sklearn import preprocessing
from scipy.linalg import svd
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA as sklearnPCA
import plotly.plotly as py
from sklearn.cluster import DBSCAN
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import f1_score, precision_score
from sklearn import preprocessing
from ggplot import *
from bokeh.charts import TimeSeries
from bokeh.models import HoverTool
from bokeh.plotting import show
from bokeh.charts import Scatter, Histogram, output_file, show
from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.io import output_notebook
from bokeh.charts import Bar, output_file, show
import bokeh.palettes as palettes
from bokeh.models import HoverTool, BoxSelectTool, Legend
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
# Out:
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# ***
# Training Set
#
# Count : 2000
# ***

# %%
# Import Training Data
df_train = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/dataframes/Step1_CombinedDFs/5k_testSet/train/DEL/del_samp_2000_train.csv')
df_train_2 = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/dataframes/Step1_CombinedDFs/5k_testSet/train/DEL/del_samp_2000_train.csv')
df_train.rename(columns={'size': 'Size'}, inplace=True)
df_train.head(1)
# Out:
#    GTconflict  GTcons  GTsupp  Ill250.GT  Ill250.alt_alnScore_mean  \
# 0          -1       2       3        2.0                    980.25
#
#    Ill250.alt_alnScore_std  Ill250.alt_count  Ill250.alt_insertSize_mean  \
# 0                12.505499              40.0                     450.475
#
#    Ill250.alt_insertSize_std  Ill250.alt_reason_alignmentScore    ...      \
# 0                  93.652012                              40.0    ...
#
#    pacbio.ref_reason_alignmentScore  refN_cnt  refN_pct  sample  segdup_cnt  \
# 0                               3.0         0         0   HG002           0
#
#    segdup_pct      start  tandemrep_cnt  tandemrep_pct       type
# 0         0.0  115665944              1            1.0  Insertion
#
# [1 rows x 186 columns]

# %%
train_set = pd.DataFrame()
train_set = df_train_2

# %%
train_set['GTcons'].replace(0, 'Homozygous_Reference', inplace=True)
train_set['GTcons'].replace(1, 'Heterozygous_Variant', inplace=True)
train_set['GTcons'].replace(2, 'Homozygous_Variant', inplace=True)

# %% [markdown]
# ** Count of Labels in Training Set **

# %% [markdown]
# <a id='imbalance'></a>

# %%
pd.value_counts(train_set['GTcons'].values, sort=False)
# Out:
# Heterozygous_Variant    931
# Homozygous_Variant      534
# Homozygous_Reference    535
# dtype: int64

# %% [markdown]
# ***
# Test Set
#
# Count : 1893
# ***

# %% [markdown]
# <a id='hom_ref'></a>

# %%
# Import Test Data
df_test = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/dataframes/Step1_CombinedDFs/5k_testSet/test/5k.DEL.test.csv')
df_test_2 = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/dataframes/Step1_CombinedDFs/5k_testSet/test/5k.DEL.test.csv')
df_test.rename(columns={'size': 'Size'}, inplace=True)
df_test.shape
# Out:
# (3504, 187)

# %%
# Store header names in lists and find names that are NOT contained in BOTH lists
c = list(df_train.columns.values)
d = list(df_test.columns.values)
set(d) - set(c)
# Out:
# {'New_ID'}

# %%
### Drop columns that are not shared by both dataframes
df_train.drop(['Ill300x.GT'], axis=1, inplace = True)
df_train.drop(['Ill250.GT'], axis=1, inplace = True)
df_train.drop(['IllMP.GT'], axis=1, inplace = True)
df_train.drop(['TenX.GT'], axis=1, inplace = True)
df_train.drop(['pacbio.GT'], axis=1, inplace = True)
df_train.drop(['GTconflict'], axis=1, inplace = True)
df_train.drop(['GTsupp'], axis=1, inplace = True)
df_train.drop(['sample'], axis=1, inplace = True)
df_train.drop(['SVtype'], axis=1, inplace = True)
df_train.drop(['type'], axis=1, inplace = True)
df_train.drop(['id'], axis=1, inplace = True)

# %%
df_train.head(1)
# Out:
#    GTcons  Ill250.alt_alnScore_mean  Ill250.alt_alnScore_std  \
# 0       2                    980.25                12.505499
#
#    Ill250.alt_count  Ill250.alt_insertSize_mean  Ill250.alt_insertSize_std  \
# 0              40.0                     450.475                  93.652012
#
#    Ill250.alt_reason_alignmentScore  Ill250.alt_reason_insertSizeScore  \
# 0                              40.0                                0.0
#
#    Ill250.alt_reason_orientation  Ill250.amb_alnScore_mean      ...        \
# 0                            0.0                885.710692      ...
#
#    pacbio.ref_insertSize_mean  pacbio.ref_insertSize_std  \
# 0                 9194.666667                5028.601219
#
#    pacbio.ref_reason_alignmentScore  refN_cnt  refN_pct  segdup_cnt  \
# 0                               3.0         0         0           0
#
#    segdup_pct      start  tandemrep_cnt  tandemrep_pct
# 0         0.0  115665944              1            1.0
#
# [1 rows x 175 columns]

# %%
df_train['chrom'].replace('X', 23, inplace=True)
df_train['chrom'].replace('Y', 24, inplace=True)
df_test['chrom'].replace('X', 23, inplace=True)
df_test['chrom'].replace('Y', 24, inplace=True)

# %%
# Store header names in lists and find names that are NOT contained in BOTH lists
c = list(df_train.columns.values)
d = list(df_test.columns.values)
set(d) - set(c)
# Out:
# {'GTconflict',
#  'GTsupp',
#  'Ill250.GT',
#  'Ill300x.GT',
#  'IllMP.GT',
#  'New_ID',
#  'SVtype',
#  'TenX.GT',
#  'id',
#  'pacbio.GT',
#  'sample',
#  'type'}

# %%
### Drop columns that are not shared by both dataframes
df_test.drop(['Ill300x.GT'], axis=1, inplace = True)
df_test.drop(['Ill250.GT'], axis=1, inplace = True)
df_test.drop(['IllMP.GT'], axis=1, inplace = True)
df_test.drop(['TenX.GT'], axis=1, inplace = True)
df_test.drop(['pacbio.GT'], axis=1, inplace = True)
df_test.drop(['GTconflict'], axis=1, inplace = True)
df_test.drop(['GTsupp'], axis=1, inplace = True)
df_test.drop(['sample'], axis=1, inplace = True)
df_test.drop(['SVtype'], axis=1, inplace = True)
df_test.drop(['type'], axis=1, inplace = True)
df_test.drop(['id'], axis=1, inplace = True)
df_test.drop(['New_ID'], axis=1, inplace = True)

# %% [markdown]
# ***
# Import '-1' Labeled Data (Unknown Data)
# ***

# %%
# Import Test Data
# SVanalyzer generated training data
df_min1 = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/dataframes/Step1_CombinedDFs/min1_DFs/DEL/del_HG002_min1.csv')
df_min1_2 = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/dataframes/Step1_CombinedDFs/min1_DFs/DEL/del_HG002_min1.csv')
df_min1.rename(columns={'size': 'Size'}, inplace=True)
df_min1.drop(['New_ID'], axis=1, inplace = True)
df_min1.drop(['index'], axis=1, inplace = True)
df_min1.shape
# Out:
# (1241, 188)

# %%
df_min1['chrom'].replace('X', 23, inplace=True)
df_min1['chrom'].replace('Y', 24, inplace=True)

# %%
### Drop columns that are not shared by both dataframes
df_min1.drop(['Ill300x.GT'], axis=1, inplace = True)
df_min1.drop(['Ill250.GT'], axis=1, inplace = True)
df_min1.drop(['IllMP.GT'], axis=1, inplace = True)
df_min1.drop(['TenX.GT'], axis=1, inplace = True)
df_min1.drop(['pacbio.GT'], axis=1, inplace = True)
df_min1.drop(['GTconflict'], axis=1, inplace = True)
df_min1.drop(['GTsupp'], axis=1, inplace = True)
df_min1.drop(['sample'], axis=1, inplace = True)
df_min1.drop(['SVtype'], axis=1, inplace = True)
df_min1.drop(['type'], axis=1, inplace = True)
df_min1.drop(['id'], axis=1, inplace = True)

# %% [markdown]
# ***
# Impute missing values using KNN
# ***

# %%
# Store training data in a new variable which will be converted to a matrix
X = df_train
X.head(3)
# Out:
#    GTcons  Ill250.alt_alnScore_mean  Ill250.alt_alnScore_std  \
# 0       2                980.250000                12.505499
# 1       1                892.818182                12.740902
# 2       0                  0.000000                 0.000000
#
#    Ill250.alt_count  Ill250.alt_insertSize_mean  Ill250.alt_insertSize_std  \
# 0              40.0                  450.475000                  93.652012
# 1              11.0                  433.636364                  73.662958
# 2               0.0                    0.000000                   0.000000
#
#    Ill250.alt_reason_alignmentScore  Ill250.alt_reason_insertSizeScore  \
# 0                              40.0                                0.0
# 1                              11.0                                0.0
# 2                               0.0                                0.0
#
#    Ill250.alt_reason_orientation  Ill250.amb_alnScore_mean      ...        \
# 0                            0.0                885.710692      ...
# 1                            0.0                850.712575      ...
# 2                            0.0                822.560976      ...
#
#    pacbio.ref_insertSize_mean  pacbio.ref_insertSize_std  \
# 0                 9194.666667                5028.601219
# 1                11212.400000                3158.955498
# 2                11245.000000                4495.349208
#
#    pacbio.ref_reason_alignmentScore  refN_cnt  refN_pct  segdup_cnt  \
# 0                               3.0         0         0           0
# 1                               5.0         0         0           0
# 2                               4.0         0         0           0
#
#    segdup_pct      start  tandemrep_cnt  tandemrep_pct
# 0         0.0  115665944              1       1.000000
# 1         0.0   44082644              0       0.000000
# 2         0.0  122935037              1       0.187135
#
# [3 rows x 175 columns]

# %%
# Convert dataframe to matrix
X=X.as_matrix()

#Imput missing values from three closest observations
X_imputed=KNN(k=3).complete(X)
X=pd.DataFrame(X_imputed)
# Out:
# Imputing row 1/2000 with 2 missing, elapsed time: 3.026
# Imputing row 101/2000 with 3 missing, elapsed time: 3.042
# Imputing row 201/2000 with 0 missing, elapsed time: 3.055
# Imputing row 301/2000 with 0 missing, elapsed time: 3.068
# Imputing row 401/2000 with 0 missing, elapsed time: 3.074
# Imputing row 501/2000 with 3 missing, elapsed time: 3.085
# Imputing row 601/2000 with 2 missing, elapsed time: 3.091
# Imputing row 701/2000 with 3 missing, elapsed time: 3.101
# Imputing row 801/2000 with 0 missing, elapsed time: 3.115
# Imputing row 901/2000 with 3 missing, elapsed time: 3.123
# Imputing row 1001/2000 with 2 missing, elapsed time: 3.135
# Imputing row 1101/2000 with 2 missing, elapsed time: 3.157
# Imputing row 1201/2000 with 0 missing, elapsed time: 3.167
# Imputing row 1301/2000 with 0 missing, elapsed time: 3.180
# Imputing row 1401/2000 with 0 missing, elapsed time: 3.190
# Imputing row 1501/2000 with 2 missing, elapsed time: 3.201
# Imputing row 1601/2000 with 0 missing, elapsed time: 3.208
# Imputing row 1701/2000 with 0 missing, elapsed time: 3.218
# Imputing row 1801/2000 with 0 missing, elapsed time: 3.230
# Imputing row 1901/2000 with 0 missing, elapsed time: 3.247

# %%
# Store header values in a list, will be used later to re-label the matrix post KNN imputation
dftrain_header = list(df_train.columns.values)
X.columns = dftrain_header
X.head(3)
# Out:
#    GTcons  Ill250.alt_alnScore_mean  Ill250.alt_alnScore_std  \
# 0     2.0                980.250000                12.505499
# 1     1.0                892.818182                12.740902
# 2     0.0                  0.000000                 0.000000
#
#    Ill250.alt_count  Ill250.alt_insertSize_mean  Ill250.alt_insertSize_std  \
# 0              40.0                  450.475000                  93.652012
# 1              11.0                  433.636364                  73.662958
# 2               0.0                    0.000000                   0.000000
#
#    Ill250.alt_reason_alignmentScore  Ill250.alt_reason_insertSizeScore  \
# 0                              40.0                                0.0
# 1                              11.0                                0.0
# 2                               0.0                                0.0
#
#    Ill250.alt_reason_orientation  Ill250.amb_alnScore_mean      ...        \
# 0                            0.0                885.710692      ...
# 1                            0.0                850.712575      ...
# 2                            0.0                822.560976      ...
#
#    pacbio.ref_insertSize_mean  pacbio.ref_insertSize_std  \
# 0                 9194.666667                5028.601219
# 1                11212.400000                3158.955498
# 2                11245.000000                4495.349208
#
#    pacbio.ref_reason_alignmentScore  refN_cnt  refN_pct  segdup_cnt  \
# 0                               3.0       0.0       0.0         0.0
# 1                               5.0       0.0       0.0         0.0
# 2                               4.0       0.0       0.0         0.0
#
#    segdup_pct        start  tandemrep_cnt  tandemrep_pct
# 0         0.0  115665944.0            1.0       1.000000
# 1         0.0   44082644.0            0.0       0.000000
# 2         0.0  122935037.0            1.0       0.187135
#
# [3 rows x 175 columns]

# %%
# Store Labels in a new 'Y' DataFrame
Y = pd.DataFrame()
Y = X['GTcons']

# %%
#Count the number of labels
pd.value_counts(Y.values, sort=False)
# Out:
# 2.0    534
# 1.0    931
# 0.0    535
# dtype: int64

# %%
# Remove labels from feature set
X.drop(['GTcons'],axis=1, inplace = True)

# %%
# Order features
X4 = X.reindex_axis(sorted(X.columns), axis=1)

# %% [markdown]
# ***
# Machine Learning
# ***

# %% [markdown]
# <a id='machine_learning'></a>

# %% [markdown]
# ** Train Random Forest Classifier **

# %% [markdown]
# <a id='multi_run'></a>

# %% [markdown]
# ** Determine Number of trees: Out of Bag Error **

# %%
# Train Test Split
# Train on 70% of the data and test on 30%
X_train, X_test, y_train, y_test = train_test_split(X4, Y, test_size=0.3)

# %%
# Train Random Forest Classifier
model = RandomForestClassifier(oob_score=True) 
model.fit(X_train, y_train)
# Out:
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
print('The OOB prediction of accuracy is: {oob}%'.format(oob=model.oob_score_ * 100))
# Out:
# The OOB prediction of accuracy is: 94.21428571428572%

# %%
sns.set_style("white")

# %%
n_estimators = 150
trees = []
oob = []
for i in range(1, n_estimators):
    model.set_params(n_estimators=i)
    model.fit(X_train, y_train)
    trees += [i]
    oob += [model.oob_score_] 
    
    
df_oob = pd.DataFrame()
df_oob['trees'] = trees
df_oob['oob'] = oob


plt.plot(trees, oob)

plt.xlabel("Number of Trees [n_estimators]")
plt.ylabel("OOB error rate")
plt.legend(loc="upper right")
plt.ylim(0, 1.0)
plt.savefig('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/del_alldata_2000_trees_oob_60.png', bbox_inches='tight')
plt.show()
# Out:
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/sklearn/ensemble/forest.py:453: UserWarning:
#
# Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning:
#
# No labelled objects found. Use label='...' kwarg on individual plots.

# %% [markdown]
# ** Train Model Using Optimal Tuning Parameters**

# %%
model = RandomForestClassifier(n_estimators=60, random_state=4, class_weight="balanced") 
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=60, n_jobs=1, oob_score=False, random_state=4,
#             verbose=0, warm_start=False)

# %%
feature_importances = pd.Series(model.feature_importances_, index=X_train.columns)

# %%
feature_importances = pd.Series(model.feature_importances_, index=X_train.columns)
feature_importances.sort()
feature_importances.plot(kind="barh", figsize=(8,30))
plt.savefig('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/del_alldata_2000_featImp_60.png', bbox_inches='tight')
plt.show()
# Out:
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning:
#
# sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
feature_importances.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/del_alldata_2000_featImp.csv')

# %%
X_ = X4[['Ill250.alt_alnScore_std','Ill300x.ref_count','Ill300x.ref_reason_alignmentScore','Ill250.alt_insertSize_std','pacbio.ref_count','Ill250.ref_count','Ill250.alt_insertSize_mean','pacbio.ref_alnScore_std','Ill250.alt_count','pacbio.alt_reason_alignmentScore','Ill300x.alt_count','pacbio.alt_alnScore_std','Ill250.alt_reason_alignmentScore','pacbio.ref_reason_alignmentScore','pacbio.ref_insertSize_mean','Ill300x.alt_reason_alignmentScore','Ill250.ref_insertSize_std','pacbio.alt_alnScore_mean','pacbio.alt_insertSize_std','pacbio.ref_insertSize_std','Ill250.ref_reason_alignmentScore','IllMP.ref_reason_alignmentScore','Ill250.ref_alnScore_std','Ill300x.alt_insertSize_std','IllMP.ref_insertSize_std']]

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(X_.corr(), annot=True, fmt=".2f")
plt.xticks(rotation='vertical')
plt.yticks(rotation='horizontal')
plt.savefig('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/del_alldata_2000_heatmap_60.png', bbox_inches='tight')
plt.show()

# %%
pred = model.predict(X_test)

# %%
print('Precision score of the training subset: {:.3f}'.format(precision_score(y_test, pred, average='micro'))) 
from sklearn.metrics import accuracy_score
print('Accuracy score of the training subset: {:.3f}'.format(accuracy_score(y_test, pred)))
# Out:
# Precision score of the training subset: 0.988
# Accuracy score of the training subset: 0.988

# %%
# Add original labels and predicted labels back to the original dataframe
df_Xtest = pd.DataFrame(X_test)
labels = pd.DataFrame(y_test)

# %%
df_Xtest['predicted_label'] = pred
df_Xtest['GTcons'] = df_train['GTcons']
df_Xtest['chrom'] = df_train['chrom']
df_Xtest['start'] = df_train['start']
df_Xtest['end'] = df_train['end']

# %%
df_Xtest['GTcons'].replace(0.0, 'Homozygous_Reference', inplace=True)
df_Xtest['GTcons'].replace(1.0, 'Heterozygous_Variant', inplace=True)
df_Xtest['GTcons'].replace(2.0, 'Homozygous_Variant', inplace=True)
df_Xtest['predicted_label'].replace(0.0, 'Homozygous_Reference', inplace=True)
df_Xtest['predicted_label'].replace(1.0, 'Heterozygous_Variant', inplace=True)
df_Xtest['predicted_label'].replace(2.0, 'Homozygous_Variant', inplace=True)

# %%
pd.value_counts(df_Xtest['GTcons'].values, sort=False)
# Out:
# Heterozygous_Variant    286
# Homozygous_Variant      170
# Homozygous_Reference    144
# dtype: int64

# %%
pd.value_counts(df_Xtest['predicted_label'].values, sort=False)
# Out:
# Heterozygous_Variant    286
# Homozygous_Variant      170
# Homozygous_Reference    144
# dtype: int64

# %%
from sklearn.metrics import confusion_matrix
ytest = df_Xtest['GTcons']
predict = df_Xtest['predicted_label']
print(confusion_matrix(ytest, predict))
# Out:
# [[283   1   2]
#  [  2 142   0]
#  [  1   1 168]]

# %%
pd.crosstab(ytest, predict, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted             Heterozygous_Variant  Homozygous_Reference  \
# True
# Heterozygous_Variant                   283                     1
# Homozygous_Reference                     2                   142
# Homozygous_Variant                       1                     1
# All                                    286                   144
#
# Predicted             Homozygous_Variant  All
# True
# Heterozygous_Variant                   2  286
# Homozygous_Reference                   0  144
# Homozygous_Variant                   168  170
# All                                  170  600

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, predict))
# Out:
#                       precision    recall  f1-score   support
#
# Heterozygous_Variant       0.99      0.99      0.99       286
# Homozygous_Reference       0.99      0.99      0.99       144
#   Homozygous_Variant       0.99      0.99      0.99       170
#
#          avg / total       0.99      0.99      0.99       600

# %% [markdown]
# ***
# Predict
#
# Predict labels for test set
# ***

# %% [markdown]
# ** Load Data **

# %%
df_test.drop(['GTcons'],axis=1, inplace=True)
X2 = df_test

# %% [markdown]
# ** Impute missing values using KNN **

# %%
#Convert dataframe to matrix
X2=X2.as_matrix()
X2=pd.DataFrame(X2)

# Imput missing values from three closest observations
X2_imputed=KNN(k=3).complete(X2)
X2=pd.DataFrame(X2_imputed)
# Out:
# Imputing row 1/3504 with 0 missing, elapsed time: 10.595
# Imputing row 101/3504 with 0 missing, elapsed time: 10.613
# Imputing row 201/3504 with 0 missing, elapsed time: 10.625
# Imputing row 301/3504 with 0 missing, elapsed time: 10.640
# Imputing row 401/3504 with 1 missing, elapsed time: 10.652
# Imputing row 501/3504 with 0 missing, elapsed time: 10.660
# Imputing row 601/3504 with 0 missing, elapsed time: 10.676
# Imputing row 701/3504 with 0 missing, elapsed time: 10.690
# Imputing row 801/3504 with 59 missing, elapsed time: 10.697
# Imputing row 901/3504 with 0 missing, elapsed time: 10.708
# Imputing row 1001/3504 with 1 missing, elapsed time: 10.718
# Imputing row 1101/3504 with 3 missing, elapsed time: 10.734
# Imputing row 1201/3504 with 1 missing, elapsed time: 10.745
# Imputing row 1301/3504 with 0 missing, elapsed time: 10.755
# Imputing row 1401/3504 with 1 missing, elapsed time: 10.778
# Imputing row 1501/3504 with 0 missing, elapsed time: 10.795
# Imputing row 1601/3504 with 3 missing, elapsed time: 10.804
# Imputing row 1701/3504 with 1 missing, elapsed time: 10.816
# Imputing row 1801/3504 with 3 missing, elapsed time: 10.831
# Imputing row 1901/3504 with 0 missing, elapsed time: 10.845
# Imputing row 2001/3504 with 1 missing, elapsed time: 10.863
# Imputing row 2101/3504 with 1 missing, elapsed time: 10.876
# Imputing row 2201/3504 with 0 missing, elapsed time: 10.888
# Imputing row 2301/3504 with 0 missing, elapsed time: 10.906
# Imputing row 2401/3504 with 0 missing, elapsed time: 10.917
# Imputing row 2501/3504 with 1 missing, elapsed time: 10.927
# Imputing row 2601/3504 with 0 missing, elapsed time: 10.945
# Imputing row 2701/3504 with 1 missing, elapsed time: 10.961
# Imputing row 2801/3504 with 3 missing, elapsed time: 10.968
# Imputing row 2901/3504 with 1 missing, elapsed time: 10.977
# Imputing row 3001/3504 with 0 missing, elapsed time: 10.987
# Imputing row 3101/3504 with 0 missing, elapsed time: 11.000
# Imputing row 3201/3504 with 1 missing, elapsed time: 11.007
# Imputing row 3301/3504 with 0 missing, elapsed time: 11.022
# Imputing row 3401/3504 with 1 missing, elapsed time: 11.038
# Imputing row 3501/3504 with 3 missing, elapsed time: 11.051

# %%
df_test_header = list(df_test.columns.values)
X2.columns = df_test_header
X2.head(3)
# Out:
#    Ill250.alt_alnScore_mean  Ill250.alt_alnScore_std  Ill250.alt_count  \
# 0                980.534884                24.312260              43.0
# 1                982.200000                12.175385              25.0
# 2                983.179487                 5.750682              39.0
#
#    Ill250.alt_insertSize_mean  Ill250.alt_insertSize_std  \
# 0                  444.790698                  85.191046
# 1                  419.560000                  60.020716
# 2                  397.512820                  75.999957
#
#    Ill250.alt_reason_alignmentScore  Ill250.alt_reason_insertSizeScore  \
# 0                              42.0                                1.0
# 1                              25.0                                0.0
# 2                              39.0                                0.0
#
#    Ill250.alt_reason_orientation  Ill250.amb_alnScore_mean  \
# 0                            0.0                863.292398
# 1                            0.0                850.880000
# 2                            0.0                907.336634
#
#    Ill250.amb_alnScore_std      ...        pacbio.ref_insertSize_mean  \
# 0               160.008066      ...                              0.00
# 1               170.692781      ...                           8671.60
# 2               141.925150      ...                          10437.35
#
#    pacbio.ref_insertSize_std  pacbio.ref_reason_alignmentScore  refN_cnt  \
# 0                   0.000000                               0.0       0.0
# 1                3889.530045                              15.0       0.0
# 2                3673.796705                              20.0       0.0
#
#    refN_pct  segdup_cnt  segdup_pct       start  tandemrep_cnt  tandemrep_pct
# 0       0.0         0.0         0.0  95498964.0            1.0       0.117089
# 1       0.0         1.0         1.0  14399929.0            1.0       1.000000
# 2       0.0         0.0         0.0  76766532.0            0.0       0.000000
#
# [3 rows x 174 columns]

# %%
X3 = pd.DataFrame()
X3 = X2
X3.head(3)
# Out:
#    Ill250.alt_alnScore_mean  Ill250.alt_alnScore_std  Ill250.alt_count  \
# 0                980.534884                24.312260              43.0
# 1                982.200000                12.175385              25.0
# 2                983.179487                 5.750682              39.0
#
#    Ill250.alt_insertSize_mean  Ill250.alt_insertSize_std  \
# 0                  444.790698                  85.191046
# 1                  419.560000                  60.020716
# 2                  397.512820                  75.999957
#
#    Ill250.alt_reason_alignmentScore  Ill250.alt_reason_insertSizeScore  \
# 0                              42.0                                1.0
# 1                              25.0                                0.0
# 2                              39.0                                0.0
#
#    Ill250.alt_reason_orientation  Ill250.amb_alnScore_mean  \
# 0                            0.0                863.292398
# 1                            0.0                850.880000
# 2                            0.0                907.336634
#
#    Ill250.amb_alnScore_std      ...        pacbio.ref_insertSize_mean  \
# 0               160.008066      ...                              0.00
# 1               170.692781      ...                           8671.60
# 2               141.925150      ...                          10437.35
#
#    pacbio.ref_insertSize_std  pacbio.ref_reason_alignmentScore  refN_cnt  \
# 0                   0.000000                               0.0       0.0
# 1                3889.530045                              15.0       0.0
# 2                3673.796705                              20.0       0.0
#
#    refN_pct  segdup_cnt  segdup_pct       start  tandemrep_cnt  tandemrep_pct
# 0       0.0         0.0         0.0  95498964.0            1.0       0.117089
# 1       0.0         1.0         1.0  14399929.0            1.0       1.000000
# 2       0.0         0.0         0.0  76766532.0            0.0       0.000000
#
# [3 rows x 174 columns]

# %%
# Order features
X5 = X2.reindex_axis(sorted(X2.columns), axis=1)

# %%
pred = model.predict(X5)
pred_prob = model.predict_proba(X5)
pred_prob_log = model.predict_log_proba(X5)

# %%
X5['predicted_label'] = pred
X5['chrom'] = df_test_2['chrom']
X5['GTcons'] = df_test_2['GTcons']
X5['start'] = df_test_2['start']
X5['end'] = df_test_2['end']
X5['Size'] = df_test_2['Size']
X5['GTsupp'] = df_test_2['GTsupp']

# %%
X6 = pd.concat([X5, pd.DataFrame(pred_prob, columns=['1','2','3'])])
X7 = pd.concat([X5, pd.DataFrame(pred_prob_log, columns=['1','2','3'])])
X6.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/df_alldata_2000_df1_60.csv', index=False)

# %%
X6 = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/df_alldata_2000_df1_60.csv')

# %%
X6.rename(columns={'1': 'Homozygous_Reference_GTcons'}, inplace=True)
X6.rename(columns={'2': 'Heterozygous_Variant_GTcons'}, inplace=True)
X6.rename(columns={'3': 'Homozygous_Variant_GTcons'}, inplace=True)
X6.rename(columns={'predicted_label': 'predicted_GTcons_label'}, inplace=True)

# %%
X6.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/df_alldata_2000_df2_60.csv', index=False)

# %%
X6['GTcons'].dtypes
# Out:
# dtype('int64')

# %%
# Drop NaN Labels
X6 = X6[np.isfinite(X6['GTcons'])]
X6 = X6[np.isfinite(X6['predicted_GTcons_label'])]

# %% [markdown]
# ***
# Label Analysis
# ***

# %%
from sklearn.metrics import confusion_matrix
consensus_GT = X6['GTcons']
predict = X6['predicted_GTcons_label']
print(confusion_matrix(consensus_GT, predict))
# Out:
# [[ 865   53    3]
#  [   0 1893   19]
#  [   1   52  618]]

# %%
X6['GTcons'].replace(0, 'Homozygous_Reference', inplace=True)
X6['GTcons'].replace(1, 'Heterozygous_Variant', inplace=True)
X6['GTcons'].replace(2, 'Homozygous_Variant', inplace=True)
X6['predicted_GTcons_label'].replace(0.0, 'Homozygous_Reference', inplace=True)
X6['predicted_GTcons_label'].replace(1.0, 'Heterozygous_Variant', inplace=True)
X6['predicted_GTcons_label'].replace(2.0, 'Homozygous_Variant', inplace=True)

# %%
print('Precision score of the prediction subset: {:.3f}'.format(precision_score(consensus_GT, predict, average='micro'))) 
print('Accuracy score of the prediction subset: {:.3f}'.format(accuracy_score(consensus_GT, predict)))
# Out:
# Precision score of the prediction subset: 0.963
# Accuracy score of the prediction subset: 0.963

# %%
pd.crosstab(consensus_GT, predict, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted             Heterozygous_Variant  Homozygous_Reference  \
# True
# Heterozygous_Variant                  1893                     0
# Homozygous_Reference                    53                   865
# Homozygous_Variant                      52                     1
# All                                   1998                   866
#
# Predicted             Homozygous_Variant   All
# True
# Heterozygous_Variant                  19  1912
# Homozygous_Reference                   3   921
# Homozygous_Variant                   618   671
# All                                  640  3504

# %%
conf_mat = pd.crosstab(consensus_GT, predict, rownames=['True'], colnames=['Predicted'], margins=True)
conf_mat.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/2000_confMatrix_60.csv')

# %% [markdown]
# ** Labels with Pred_Prob >=0.9 **

# %%
high_conf_labels = X6[(X6['Homozygous_Reference_GTcons'] == 1) | (X6['Homozygous_Reference_GTcons'] >= 0.9) | (X6['Heterozygous_Variant_GTcons'] == 1) | (X6['Heterozygous_Variant_GTcons'] >= 0.9) | (X6['Homozygous_Variant_GTcons'] == 1) | (X6['Homozygous_Variant_GTcons'] >= 0.9)]

# %%
consensus_GT = high_conf_labels['GTcons']
predict = high_conf_labels['predicted_GTcons_label']
pd.crosstab(consensus_GT, predict, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted             Heterozygous_Variant  Homozygous_Reference  \
# True
# Heterozygous_Variant                  1617                     0
# Homozygous_Reference                     0                   659
# Homozygous_Variant                       0                     0
# All                                   1617                   659
#
# Predicted             Homozygous_Variant   All
# True
# Heterozygous_Variant                   0  1617
# Homozygous_Reference                   0   659
# Homozygous_Variant                   496   496
# All                                  496  2772

# %%
consensus_GT = high_conf_labels['GTcons']
predict = high_conf_labels['predicted_GTcons_label']
conf_mat = pd.crosstab(consensus_GT, predict, rownames=['True'], colnames=['Predicted'], margins=True)
conf_mat.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/2000_confMatrix_hi_60.csv')

# %%
print(classification_report(consensus_GT, predict))
# Out:
#                       precision    recall  f1-score   support
#
# Heterozygous_Variant       1.00      1.00      1.00      1617
# Homozygous_Reference       1.00      1.00      1.00       659
#   Homozygous_Variant       1.00      1.00      1.00       496
#
#          avg / total       1.00      1.00      1.00      2772

# %% [markdown]
# ***
# Predict
#
# Predict labels for minus 1 (unknown label) set
# ***

# %% [markdown]
# ** Load Data **

# %%
df_min1.drop(['GTcons'],axis=1, inplace=True)
X2 = df_min1

# %% [markdown]
# ** Impute missing values using KNN **

# %%
#Convert dataframe to matrix
X2=X2.as_matrix()
X2=pd.DataFrame(X2)

# Imput missing values from three closest observations
X2_imputed=KNN(k=3).complete(X2)
X2=pd.DataFrame(X2_imputed)

# %%
df_min1_header = list(df_min1.columns.values)
X2.columns = df_min1_header
X2.head(3)

# %%
X3 = pd.DataFrame()
X3 = X2
X3.head(3)

# %%
# Order features
X5 = X2.reindex_axis(sorted(X2.columns), axis=1)

# %%
pred = model.predict(X5)
pred_prob = model.predict_proba(X5)
pred_prob_log = model.predict_log_proba(X5)

# %%
X5['predicted_label'] = pred
X5['chrom'] = df_min1_2['chrom']
X5['GTcons'] = df_min1_2['GTcons']
X5['start'] = df_min1_2['start']
X5['end'] = df_min1_2['end']
X5['Size'] = df_min1_2['Size']
X5['GTsupp'] = df_min1_2['GTsupp']

# %%
X6 = pd.concat([X5, pd.DataFrame(pred_prob, columns=['1','2','3'])])
X7 = pd.concat([X5, pd.DataFrame(pred_prob_log, columns=['1','2','3'])])
X6.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/df_alldata_2000_min1_df1_60.csv', index=False)

# %%
X6 = pd.read_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/df_alldata_2000_min1_df1_60.csv')

# %%
X6.rename(columns={'1': 'Homozygous_Reference_GTcons'}, inplace=True)
X6.rename(columns={'2': 'Heterozygous_Variant_GTcons'}, inplace=True)
X6.rename(columns={'3': 'Homozygous_Variant_GTcons'}, inplace=True)
X6.rename(columns={'predicted_label': 'predicted_GTcons_label'}, inplace=True)

# %%
X6.to_csv('/Volumes/lesleydata/size_sample/Step4_ML/plots/DEL/all_data/5k_Test_Set/2000_train/dataframes/df_alldata_2000_min1_df2_60.csv')
