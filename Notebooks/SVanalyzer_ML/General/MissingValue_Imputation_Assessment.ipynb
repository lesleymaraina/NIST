# %% [markdown]
# Missing Value Impuation Assessment

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import math
from bokeh.charts import Scatter, Bar, Histogram, output_file, show
from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.io import output_notebook
import seaborn as sns

# %%
df_preimp = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/preImp.csv')
df_postimp = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp.csv')
df_postimp_10X = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp_10X.csv')
df_postimp_feat = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/postimp_feat_.csv')

# %%
sns.set_style("white")

# %%
#Size Bins
bins = [0, 0.5, 0.8,0.9,1]
group_names_size = ['0-0.5', '0.5-0.8', '0.8-0.9', '0.9-1']
df_postimp['GTcons_allmax_prob_bin'] = pd.cut(df_postimp['GTcons_allmax_prob'], bins, labels=group_names_size)

# %%
# #Size Bins
# bins = [0, 0.5, 0.8,0.9,1]
# group_names_size = ['0-0.5', '0.5-0.8', '0.8-0.9', '0.9-1']
# df_postimp_feat['GTcons_allmax_prob_bin'] = pd.cut(df_postimp_feat['GTcons_allmax_prob'], bins, labels=group_names_size)

# %%
#Size Bins
bins = [0, 0.5, 0.8,0.9,1]
group_names_size = ['0-0.5', '0.5-0.8', '0.8-0.9', '0.9-1']
df_postimp_10X['10X_max_prob_bin'] = pd.cut(df_postimp_10X['10X_max_prob'], bins, labels=group_names_size)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.boxplot(x="GTcons", y="GTcons_allmax_prob", hue="GTcons_allmax_prob_bin", data=df_postimp) 
# plt.savefig('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/All_post_imp.png', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.swarmplot(x="GTcons", y="GTcons_allmax_prob", hue="GTcons_allmax_prob_bin", data=df_postimp)
plt.savefig('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp_all_select_swarm.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.boxplot(x="GTcons", y="10X_max_prob", hue="10X_max_prob_bin", data=df_postimp_10X) 
# plt.savefig('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp_10X.png', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.swarmplot(x="GTcons", y="10X_max_prob", hue="10X_max_prob_bin", data=df_postimp_10X)
plt.savefig('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp_10X_select_swarm.png', bbox_inches='tight')

# %%
df_10X = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Oct122017_Revised_R/summary_plots/data/TenX_final_GTcons_df_DEL_SVanalyzer.csv')

# %%
df_10X['10X_max_prob'] = df_10X[['Homozygous_Reference_GTcons_TenX', 'Heterozygous_Variant_GTcons_TenX', 'Homozygous_Variant_GTcons_TenX']].max(axis=1)

# %%
#Size Bins
bins = [0, 0.5, 0.8,0.9,1]
group_names_size = ['0-0.5', '0.5-0.8', '0.8-0.9', '0.9-1']
df_10X['10X_max_prob_bin'] = pd.cut(df_10X['10X_max_prob'], bins, labels=group_names_size)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.swarmplot(x="GTcons", y="10X_max_prob", hue="10X_max_prob_bin", data=df_10X)
plt.savefig('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp_10X_all_swarm.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.boxplot(x="GTcons", y="10X_max_prob", hue="10X_max_prob_bin", data=df_10X) 
plt.savefig('/Volumes/lesleydata/SVanalyzer_ML/Imputation_Compare/post_imp_10X_all.png', bbox_inches='tight')

# %% [markdown]
# From 10X Selected Data

# %%
df_2 = df_preimp.dropna()

# %%
x = df_postimp_10X['TenX.HP2_alt_insertSize_mean_postimp']
y = df_2['TenX.HP2_alt_insertSize_mean']

# %%
plt.hist(x, bins, alpha=0.5, label='x')
plt.hist(y, bins, alpha=0.5, label='y')
plt.legend(loc='upper right')
plt.show()
