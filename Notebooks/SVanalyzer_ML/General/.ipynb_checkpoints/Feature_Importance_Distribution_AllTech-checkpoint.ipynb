# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import math
from bokeh.charts import Scatter, Bar, Histogram, output_file, show
from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.io import output_notebook
import seaborn as sns

# %%
df = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Oct272017_ML_w_AllTech/data/train_test_data/train_data_balanced.csv')
f = pd.read_csv('/Users/lmc2/NIST/Notebooks/SVanalyzer_ML/DEL/results/General/feature_importance.csv')

# %%
df_2 = df[['pacbio.ref_count','Ill300x.ref_count', 'pacbio.ref_reason_alignmentScore', 'Ill300x.ref_reason_alignmentScore', 'Ill250.alt_count', 'GTcons']]

# %%
df_2['GTcons'].replace(0.0, 'Homozygous_Reference', inplace=True)
df_2['GTcons'].replace(1.0, 'Heterozygous_Variant', inplace=True)
df_2['GTcons'].replace(2.0, 'Homozygous_Variant', inplace=True)
# Out:
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/core/generic.py:3554: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_2.head(1)
# Out:
#    Ill300x.ref_count  pacbio.ref_reason_alignmentScore  \
# 0              210.0                              54.0
#
#    Ill300x.ref_reason_alignmentScore  Ill250.alt_count                GTcons
# 0                              210.0               1.0  Homozygous_Reference

# %%
# # y = df_2[['GTcons']]
# X = df_2.ix[:, 0:4].values
# y = df_2.ix[:,4].values

# %%
# label_dict = {1:'Homozygous_Reference',
#               2:'Heterozygous_Variant',
#               3: 'Homozygous_Variant'}
# feature_dict = {0: 'pacbio.ref_count',
#                 1: 'pacbio.alt_insertSize_std',
#                 2: 'pacbio.alt_alnScore_std',
#                 3: 'Ill250.alt_count'}

# %%
# with plt.style.context('seaborn-whitegrid'):
#     plt.figure(figsize=(8,6))
#     for cnt in range(4):
#         plt.subplot(2,2, cnt+1)
#         for lab in ('Homozygous_Reference','Heterozygous_Variant','Homozygous_Variant'):
#             plt.hist(X[y==lab, cnt],
#                     label=lab,
#                     bins=10,
#                     alpha=0.3)
#             plt.xlabel(feature_dict[cnt])
#         plt.legend(loc='upper right', fancybox=True, fontsize=8)
        
#         plt.tight_layout()
#         plt.show()

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3cbd9929-21f7-4611-a1c9-3c95022a744f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# **NOTE:**
#     There was 1 NA value in each feature column and each was dropped to create the plot

# %%
df_3 = df_2.dropna()

# %%
df_3.isnull().sum()
# Out:
# Ill300x.ref_count                    0
# pacbio.ref_reason_alignmentScore     0
# Ill300x.ref_reason_alignmentScore    0
# Ill250.alt_count                     0
# GTcons                               0
# dtype: int64

# %%
p = Histogram(df_3, values='pacbio.ref_reason_alignmentScore', color='GTcons', bins=23,
              title="GTcons Label Distribution: [pacbio.ref_reason_alignmentScore]",
              legend='top_right')

output_file("pacbio.ref_reason_alignmentScore_histo.html")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4294cab7-0d57-4a23-af24-3c67bf8f2f60"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4294cab7-0d57-4a23-af24-3c67bf8f2f60").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4294cab7-0d57-4a23-af24-3c67bf8f2f60");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4294cab7-0d57-4a23-af24-3c67bf8f2f60' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3a144fef-644f-4eac-b652-b6f1d7a8470a":{"roots":{"references":[{"attributes":{"data_source":{"id":"7aacaa4a-842e-414c-966b-dff4d84faf09","type":"ColumnDataSource"},"glyph":{"id":"6926a431-3839-417a-ab3e-137542d795c2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"af475d1b-5f5a-4cc0-90e9-77048baa9543","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","y","line_alpha","width","fill_alpha","x","height","color","line_color"],"data":{"chart_index":["(9.173913, 13.260870]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[1.0],"label":["(9.173913, 13.260870]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.086956521739131],"x":["11.217391500000002"],"y":[0.5]}},"id":"f887bfe4-762a-438c-9a13-d2a86875a004","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0
type":"ColumnDataSource"},{"attributes":{"plot":{"id":"cbfadc59-d9cd-41b2-9fcc-aa89718ff1f3","subtype":"Chart","type":"Plot"}},"id":"3b31844f-2764-4aeb-bec3-346f511da2c8","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"df799f7b-e4a9-4a1a-964f-65ea13010c1d","type":"ColumnDataSource"},"glyph":{"id":"798885c0-895a-4e6c-aaba-08afbf375e92","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4de978d2-1bd3-4e3d-9997-a87024c9c77d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8f4a86d2-c1e0-4347-b03 ...

# %%
p = Histogram(df_3, values='pacbio.ref_count', color='GTcons', bins=48,
              title="PB: Reference Count",
              legend='top_right')

output_file("PB.ref_count_histo.html")

show(p)
# Out:
# ----------------------------------------------------------------------
# KeyError                             Traceback (most recent call last)
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'pacbio.ref_count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                             Traceback (most recent call last)
# <ipython-input-46-906257bb18d9> in <module>()
#       1 p = Histogram(df_3, values='pacbio.ref_count', color='GTcons', bins=48,
#       2               title="PB: Reference Count",
# ----> 3               legend='top_right')
#       4
#       5 output_file("PB.ref_count_histo.html")
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/builders/histogram_builder.py in Histogram(data, values, label, color, agg, bins, yscale, xgrid, ygrid, continuous_range, **kw)
#     105     kw['bins'] = bins
#     106
# --> 107     return create_and_build(HistogramBuilder, data, **kw)
#     108
#     109
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/builder.py in create_and_build(builder_class, *data, **kws)
#      55     chart_kws = {k: v for k, v in kws.items() if k not in builder_props}
#      56     chart = Chart(**chart_kws)
# ---> 57     chart.add_builder(builder)
#      58     chart.start_plot()
#      59
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/chart.py in add_builder(self, builder)
#     151     def add_builder(self, builder):
#     152         self._builders.append(builder)
# --> 153         builder.create(self)
#     154
#     155     def add_ranges(self, dim, range):
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/builder.py in create(self, chart)
#     512         """
#     513         # call methods that allow customized setup by subclasses
# --> 514         self.setup()
#     515         self.process_data()
#     516
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/builders/histogram_builder.py in setup(self)
#     141
#     142     def setup(self):
# --> 143         super(HistogramBuilder, self).setup()
#     144
#     145         # when we create multiple histograms, we set the alpha to support overlap
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/builders/bar_builder.py in setup(self)
#     104         # ToDo: perform aggregation validation
#     105         # Not given values kw, so using only categorical data
# --> 106         if self.values.dtype.name == 'object' and len(self.attribute_columns) == 0:
#     107             # agg must be count
#     108             self.agg = 'count'
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/properties.py in dtype(self)
#     193     @property
#     194     def dtype(self):
# --> 195         if isinstance(self.data, pd.DataFrame):
#     196             return self.data.dtypes[self.selection[0]]
#     197         else:
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/bokeh/charts/properties.py in data(self)
#     159                 return special_columns[self.selection](self._data)
#     160
# --> 161             return self._data[self.selection]
#     162
#     163     def __len__(self):
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'pacbio.ref_count'

# %%
p = Histogram(df_3, values='Ill250.alt_count', color='GTcons', bins=30
              ,
              title="GTcons Label Distribution: Illumnia 250bp alternate read count [Ill250.alt_count]",
              legend='top_right')

output_file("Ill250.alt_count_histo.html")

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'Ill250.alt_count_histo.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4b7f17ce-67e3-48e3-9f8a-c4ad223c39d4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4b7f17ce-67e3-48e3-9f8a-c4ad223c39d4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4b7f17ce-67e3-48e3-9f8a-c4ad223c39d4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4b7f17ce-67e3-48e3-9f8a-c4ad223c39d4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9cb1edac-f6b4-4184-ad80-57f18fff283e":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7630943-e574-4622-b55c-347bf80ad5c5","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"59a83c05-7954-483c-bbaa-bdbeab2a1fd7","type":"Rect"},{"attributes":{"data_source":{"id":"3361a69b-b219-4fce-a191-0815468218ce","type":"ColumnDataSource"},"glyph":{"id":"46f2fe18-2070-4f36-be44-aea0a3fbbee0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"df5d3dab-c135-4770-8e08-7eedc3458105","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"47fe0e37-5383-49e7-8011-7f79559231aa","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e146cddd-28a1-4c4b-8cd9-acdf94eefd9b","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","y","line_alpha","width","fill_alpha","x","height","color","line_color"],"data":{"chart_index":["(7.200000, 8.000000]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(7.200000, 8.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7999999999999998],"x":["7.6"],"y":[0.0]}},"id":"247bc91d-53e0-4d2c-be81-f0f24c9176a8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"98d79bd8-94c9-4c9f-acb0-d4c375f67aab","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","y","line_alpha","width","fill_alpha","x","height","color","line_color"],"data":{"chart_index":["(53.200000, 55.733333]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[8.0],"label":["(53.200000, 55.733333]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.5333333333333385],"x":["54.4666665"],"y":[4.0]}},"id":"e7cd211e-4cc8-443a-829e-90e8b2ac401e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c0b9fb8-ef67-4356-9265-364763f98c02","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","y","line_alpha","width","fill_alpha","x","height","color","line_color"],"data":{"chart_index":["(31.766667, 34.133333]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[10.0],"label":["(31.766667, 34.133333]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.366666666666667],"x":["32.95"],"y":[5.0]}},"id":"32071716-d9b4-4555-9560-bd85f4ce866e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"bca5aa21-0e77-4fd2-bb58-3b92c0533ce3","type":"ColumnDataSource"},"glyph":{"id":"a9d9fd67-6b40-40ef-b723-592ccd2f5ae0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"deafab0b-7353-45a3-b0fa-568481beddda","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","y","line_alpha","width","fill_alpha","x","height","color","line_color"],"data":{"chart_index":["(45.600000, 48.133333]"],"color":["#407ee7"],"fill_alph ...

# %% [markdown]
# **NOTE: Differing bin width**
#
# [If all values are equal, the result is a single bin with arbitrary width](http://bokeh.pydata.org/en/0.12.0/docs/reference/charts.html)

# %% [markdown]
# [Pair plot Resource](https://www.youtube.com/watch?v=cpZExlOKFH4)

# %% [markdown]
# **Variables that total 0.8627**

# %%
df_feat = df[['Ill300x.ref_count','pacbio.ref_reason_alignmentScore','Ill300x.ref_reason_alignmentScore','Ill250.alt_count','Ill250.alt_reason_alignmentScore','pacbio.ref_count','Ill250.ref_reason_alignmentScore','Ill250.ref_count','pacbio.alt_count','pacbio.alt_reason_alignmentScore','Ill250.alt_insertSize_std','pacbio.ref_insertSize_std','Ill250.alt_alnScore_std','pacbio.ref_alnScore_std','Ill300x.alt_count','Ill300x.alt_reason_alignmentScore','pacbio.alt_insertSize_std','pacbio.alt_alnScore_std','Ill300x.alt_insertSize_std','Ill250.alt_insertSize_mean','pacbio.alt_insertSize_mean','Ill250.alt_alnScore_mean','pacbio.ref_insertSize_mean','IllMP.ref_reason_alignmentScore','pacbio.ref_alnScore_mean','IllMP.ref_count','IllMP.alt_insertSize_mean','Ill250.ref_insertSize_std','IllMP.alt_reason_alignmentScore','IllMP.ref_alnScore_std','pacbio.alt_alnScore_mean','IllMP.alt_alnScore_mean', 'GTcons']]

# %%
g = sns.pairplot(df_feat, hue="GTcons")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.pairplot(df_feat, hue="GTcons")

# %%
plt.show(g)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
g
