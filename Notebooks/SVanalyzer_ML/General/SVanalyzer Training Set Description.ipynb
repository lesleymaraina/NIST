# %% [markdown]
# **SVanalyzer Training Set Description**
#
# The following notebook describes the consensus genotype (GTcons) for each of the svanalyzer training sets. One major point illustrated below is an imbalance of the number of GTcons examples in the training set.

# %%
import pandas as pd
import numpy as np
from fancyimpute import KNN
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import LeaveOneOut
from scipy.stats import ks_2samp
from scipy import stats
from matplotlib import pyplot
from sklearn import preprocessing
from scipy.linalg import svd
from sklearn.decomposition import TruncatedSVD
import sqlite3
import seaborn as sns
from bokeh.io import gridplot, output_file, show, curdoc, output_notebook
from bokeh.plotting import figure
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA as sklearnPCA
import plotly.plotly as py
from ggplot import *
from bokeh.charts import Scatter, Histogram, output_file, show
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)

# %% [markdown]
# ***
# Import Data
# ***

# %% [markdown]
# **All Data**

# %%
# Deletions
exact_del = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Exact_Match/Exact_Match_DEL.csv')
# exact_del.dropna()
Hom_Ref_DEL = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Hom_Ref/Hom_Ref_DEL.csv')
# Hom_Ref_DEL.dropna()
Inaccurate_Calls_DEL = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Inaccurate_Calls/Inaccurate_Calls_DEL.csv')
# Inaccurate_Calls_DEL.dropna()
# Insertions
exact_ins = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Exact_Match/Exact_Match_INS.csv')
# exact_ins.dropna()
Hom_Ref_INS = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Exact_Match/Exact_Match_INS.csv')
# Hom_Ref_INS.dropna()
Inaccurate_Calls_INS = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Inaccurate_Calls/Inaccurate_Calls_INS.csv')
# Inaccurate_Calls_INS.dropna()


# Combine Dataframes
Exact_Match = pd.concat([exact_del, exact_ins], axis=0)
Hom_Ref = pd.concat([Hom_Ref_DEL, Hom_Ref_INS], axis=0)
Inaccurate_Calls = pd.concat([Inaccurate_Calls_DEL, Inaccurate_Calls_INS], axis=0)

# Graphs
p1 = Histogram(Exact_Match, values='GTcons', title='ExactMatch: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Exact_Match_GTcons.html")
p2 = Histogram(Hom_Ref, values='GTcons', title='Hom Ref: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Hom_Ref_GTcons.html")
p3 = Histogram(Inaccurate_Calls, values='GTcons', title='Inaccurate Calls: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Inaccurate_Calls_GTcons.html")
# Out:
# /Users/lmc2/anaconda/envs/NIHFAES/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning:
#
# Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ** Trio Separated Data**

# %%
'''
Deletions
'''
# HG002
exact_del_HG002 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Exact_Match/exact_match_DEL_HG002.csv')
Hom_Ref_DEL_HG002 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Hom_Ref/Hom_Ref_DEL_HG002.csv')
Inaccurate_Calls_DEL_HG002 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Inaccurate_Calls/Inaccurate_Calls_DEL_HG002.csv')

#HG003
exact_del_HG003 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Exact_Match/exact_match_DEL_HG003.csv')
Hom_Ref_DEL_HG003 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Hom_Ref/Hom_Ref_DEL_HG003.csv')
Inaccurate_Calls_DEL_HG003 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Inaccurate_Calls/Inaccurate_Calls_DEL_HG003.csv')

#HG004
exact_del_HG004 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Exact_Match/exact_match_DEL_HG004.csv')
Hom_Ref_DEL_HG004 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Hom_Ref/Hom_Ref_DEL_HG004.csv')
Inaccurate_Calls_DEL_HG004 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/DEL/Inaccurate_Calls/Inaccurate_Calls_DEL_HG004.csv')

'''
Insertions
'''

# HG002
exact_ins_HG002 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Exact_Match/exact_match_INS_HG002.csv')
Hom_Ref_INS_HG002 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Hom_Ref/Hom_Ref_INS_HG002.csv')
Inaccurate_Calls_INS_HG002 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Inaccurate_Calls/Inaccurate_Calls_INS_HG002.csv')

# HG003
exact_ins_HG003 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Exact_Match/exact_match_INS_HG003.csv')
Hom_Ref_INS_HG003 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Hom_Ref/Hom_Ref_INS_HG003.csv')
Inaccurate_Calls_INS_HG003 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Inaccurate_Calls/Inaccurate_Calls_INS_HG003.csv')

#HG004
exact_ins_HG004 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Exact_Match/exact_match_INS_HG004.csv')
Hom_Ref_INS_HG004 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Hom_Ref/Hom_Ref_INS_HG004.csv')
Inaccurate_Calls_INS_HG004 = pd.read_csv('/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/data/train/INS/Inaccurate_Calls/Inaccurate_Calls_INS_HG004.csv')

# Combine Dataframes

Exact_Match_HG002 = pd.concat([exact_del_HG002, exact_ins_HG002], axis=0)
Exact_Match_HG003 = pd.concat([exact_del_HG003, exact_ins_HG003], axis=0)
Exact_Match_HG004 = pd.concat([exact_del_HG004, exact_ins_HG004], axis=0)

Hom_Ref_HG002 = pd.concat([Hom_Ref_DEL_HG002, Hom_Ref_INS_HG002], axis=0)
Hom_Ref_HG003 = pd.concat([Hom_Ref_DEL_HG003, Hom_Ref_INS_HG003], axis=0)
Hom_Ref_HG004 = pd.concat([Hom_Ref_DEL_HG004, Hom_Ref_INS_HG004], axis=0)

Inaccurate_Calls_HG002 = pd.concat([Inaccurate_Calls_DEL_HG002, Inaccurate_Calls_INS_HG002], axis=0)
Inaccurate_Calls_HG003 = pd.concat([Inaccurate_Calls_DEL_HG003, Inaccurate_Calls_INS_HG003], axis=0)
Inaccurate_Calls_HG004 = pd.concat([Inaccurate_Calls_DEL_HG004, Inaccurate_Calls_INS_HG004], axis=0)

# %% [markdown]
# ***
# Case Example
# ***

# %% [markdown]
# The following is one example selected from manual inspection of model labeled variants.
#
# Summary
# Model assigned a 316bp deletion for HG002 as a heterozygous variant with 100% certainty (1 predict probability). Preliminary R analysis assigned variant as homozygous variant. Manually inspected site to determine which is more likely to be correct.

# %% [markdown]
# ![Figure1](https://raw.githubusercontent.com/lesleymaraina/NIST/master/Notebooks/SVanalyzer_ML/DEL/images/Manual_Inspection_Example_PB.png)

# %% [markdown]
# ***
# Summary Graphs
# ***

# %% [markdown]
# **Deletions**

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f9cc53e0-34d5-4cfc-a61a-e3904a452a77">Loading BokehJS ...</span>
#     </div>

# %%
# Exact Match for each member of the trio
p1 = Histogram(exact_del_HG002, values='GTcons', title='Exact_Match_HG002 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Exact_Match_HG002_GTcons.html")
p2 = Histogram(exact_del_HG003, values='GTcons', title='Exact_Match_HG003 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Exact_Match_HG003_GTcons.html")
p3 = Histogram(exact_del_HG004, values='GTcons', title='Exact_Match_HG004 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Exact_Match_HG004_GTcons.html")
# Generate Plot Cluster
# curdoc().clear()
# p_g = gridplot([[p1, p2], [None, p3]])
# show(p_g)
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="62d6a6be-c384-410e-b15d-7bf330bfd159"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("62d6a6be-c384-410e-b15d-7bf330bfd159").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("62d6a6be-c384-410e-b15d-7bf330bfd159");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '62d6a6be-c384-410e-b15d-7bf330bfd159' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9ec5fc6e-73f0-46ff-8961-45d7a69a4894":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"
","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"35145944-6a11-418b-bbd3-80b04146b6da","type":"GlyphRenderer"},{"at ...

# %%
# Hom Ref for each member of the trio
p1 = Histogram(Hom_Ref_DEL_HG002, values='GTcons', title='Hom_Ref_HG002 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Hom_Ref_HG002_GTcons.html")
p2 = Histogram(Hom_Ref_DEL_HG003, values='GTcons', title='Hom_Ref_HG003 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Hom_Ref_HG003_GTcons.html")
p3 = Histogram(Hom_Ref_DEL_HG004, values='GTcons', title='Hom_Ref_HG004 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Hom_Ref_HG004_GTcons.html")

# Generate Plot Cluster
# curdoc().clear()
# p_g = gridplot([[p1, p2], [None, p3]])
# show(p_g)
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5f91c397-4ecd-4975-9c81-1c6df3125b3d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5f91c397-4ecd-4975-9c81-1c6df3125b3d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5f91c397-4ecd-4975-9c81-1c6df3125b3d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5f91c397-4ecd-4975-9c81-1c6df3125b3d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e7d0ccf0-ef37-4ea4-9bb4-946085438f2d":{"roots":{"references":[{"attributes":{},"id":"dbb9b18d-01f8-4d5c-9d4c-a211866aa7bd","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(0.333333, 0.466667]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.333333, 0.466667]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["0.4"],"y":[0.0]}},"id":"6fb89740-e963-45c1-9f55-8f3fe5ed5b90","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"58d16224-1a42-44f5-989b-54632adddfe1","type":"ColumnDataSource"},"glyph":{"id":"4e3b2343-377c-4f1e-bb29-5e39c239239c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e9cf5bc5-0044-46df-a99a-63a3f08de41a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(0.066667, 0.200000]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.066667, 0.200000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["0.1333335"],"y":[0.0]}},"id":"ac7327a3-cbc3-47de-b014-abebacaadfcd","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(0.200000, 0.333333]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.200000, 0.333333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["0.26666650000000003"],"y":[0.0]}},"id":"6db27fcc-447f-4a3e-90d0-787cf5bb4a19","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5f21f9ec-0c0e-4654-b197-e7b56c57115b","subtype":"Chart","type":"Plot"}},"id":"42403aac-78aa-47ea-97ea-fa89bbdea1d0","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(0.600000, 0.733333]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.600000, 0.733333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["0.6666665"],"y":[0.0]}},"id":"5a03c21d-2731-4e71-886d-345a4d0b3194","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["[-1.000000, -0.866667]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[24.0],"label":["[-1.000000, -0.866667]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["-0.9333335"],"y":[12.0]}},"id":"cd6865c6-38fb-4a4a-bd2b-05077dd0db3f","type":"ColumnDataSource"},{"attributes":{"location":"top_left","plot":{"id":"5f21f9ec-0c0e-4654-b197-e7b56c57115b","subtype":"Chart","type":"Plot"}},"id":"79a22795-a773-4057-8be0-9ab8553342cc","type":"Legend"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(-0.466667, -0.333333]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(-0.466667, -0.333333]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["-0.4"],"y":[0.0]}},"id":"876e0322-ba07-4f61-b1d2-1c59d01c00fc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ea82106e-b3a8-4133-a6c2-07cbd29f2ab6","type":"ColumnDataSource"},"glyph":{"id":"a17a7455-ef8b-4140-8175-292b1eec0305","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5608d22c-add3-4254-adce-e9f6fec08e08","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":1.0000001666666667,"start":-1.0000001666666667},"id":"8667ff29-1395-4ae6-99ef-cebd945268a5","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color ...

# %%
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="14e7769d-bc71-4c9f-bfd1-8df534560f48"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("14e7769d-bc71-4c9f-bfd1-8df534560f48").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("14e7769d-bc71-4c9f-bfd1-8df534560f48");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '
type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"644bc348-ed38-47f4-a341-a6415b9a7393","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8f5090ef-5f43-47ea-b02c-c58257dfc69d","type":"ColumnDataSource"},"glyph":{"id":"259ee403-3668-4c1f-8052-86f18ef69033","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b4ea94a8-a87a-4842-8ec9-0eedf3d77834","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(0.066667, 0.200000]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.066667, 0.200000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["0.1333335"],"y":[0.0]}},"id":"8652bf95-7d6a-4b82-9d00-087f63cd4e8c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e7415fbb-2503-4b37-93e0-50931c29b84d","type":"ColumnDataSource"},"glyph":{"id":"ec652d47-4aca-4a5f-ba64-2cb5d1e16619","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c054207c-f4c7-422b-90eb-6bd9759fc89d","type":"GlyphRenderer"},{"attributes":{"axis_label":"Frequency","formatter":{"id":"098420aa-b161-4af9-9fcf-9d37541690e8","type":"BasicTickFormatter"},"plot":{"id":"ac8f28b2-9893-4c07-8878-85658daf0835","subtype":"Chart","type":"Plot"},"ticker":{"id":"5c88cec6-72ee-4e38-8295-fada435121cf","type":"BasicTicker"}},"id":"f5955ae8-8d44-47b0-ac79-a405c3b7aaab","type":"LinearAxis"},{"attributes":{},"id":"aa424ddc-d4af-4f76-8cb9-d1d0d6f00989","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"bb9bce23-997f-4a62-85d7-3b922c05edb9","type":"ColumnDataSource"},"glyph":{"id":"75ed1891-566b-46ed-83ca-9169a9df6033","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"03e21174-3b4f-48b1-9c0c-a7b6b05c106a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["[-1.000000, -0.866667]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[32.0],"label":["[-1.000000, -0.866667]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.1333333333333333],"x":["-0.9333335"],"y":[16.0]}},"id":"5b46839d-dcb2-4fce-87de-3987803ea4e8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2b7e80d0-8258-4f0c-b803-e151be85d3f8","type":"ColumnDataSource"},"glyph":{"id":"b0cdfcf5-9732-40bc-8ac4-f1fec6f9de6c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ff42e192-ab72-4523-a000-41a63785604e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","x","color","line_color","label","height","width","line_alpha"],"data":{"chart_index":["(-0.733333, -0.600000]"],"color":["LightSlateGray"],"fill_alpha":[0.8],"height":[0.0],"label":["(-0.733333, -0.600000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.13333333333333341],"x":["-0.6666665"],"y":[0.0]}},"id":"204d74f0-078e-4b48-a2a5-379a5555fbd6","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ac8f28b2-9893-4c07-8878-85658daf0835","subtype":"Chart","type":"Plot"}},"id":"59c9316c-b656-45fa-8ea8-d40e020fcf75","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"he ...

# %%
# Inaccurate Calls for each member of the trio
p1 = Histogram(Inaccurate_Calls_HG002, values='GTcons', title='Inaccurate_Calls_HG002 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Inaccurate_Calls_HG002_GTcons.html")
p2 = Histogram(Inaccurate_Calls_HG003, values='GTcons', title='Inaccurate_Calls_HG003 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Inaccurate_Calls_HG003_GTcons.html")
p3 = Histogram(Inaccurate_Calls_HG004, values='GTcons', title='Inaccurate_Calls_HG004 [DEL]: Consensust GT', color='LightSlateGray', bins=15, plot_height=250, xlabel="GTcons", ylabel="Frequency")
# output_file("/Volumes/lesleydata/SVanalyzer_ML/Sept122017/Step3_ML/graphs/summary_graphs/Inaccurate_Calls_HG004_GTcons.html")


# Generate Plot Cluster
# curdoc().clear()
# p_g = gridplot([[p1, p2], [None, p3]])
# show(p_g)
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0821d63-bab6-41bd-a2ce-8be2d3717185"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c0821d63-bab6-41bd-a2ce-8be2d3717185").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0821d63-bab6-41bd-a2ce-8be2d3717185");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0821d63-bab6-41bd-a2ce-8be2d3717185' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"